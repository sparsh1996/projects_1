# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import os
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm
# %matplotlib inline

# %%
train = pd.read_csv('/Users/skylark/Desktop/upvotes/train.csv')
test = pd.read_csv('/Users/skylark/Desktop/upvotes/test.csv')

# %%
data_x = train.drop(['ID', 'Tag', 'Upvotes', 'Username'], axis=1)

# %%
data_x
# Out:
#         Reputation  Answers    Views
# 0           3942.0      2.0   7855.0
# 1          26046.0     12.0  55801.0
# 2           1358.0      4.0   8067.0
# 3            264.0      3.0  27064.0
# 4           4271.0      4.0  13986.0
# ...            ...      ...      ...
# 330040        36.0      2.0   1063.0
# 330041      1649.0      2.0  23319.0
# 330042      6178.0      2.0   2453.0
# 330043        89.0      2.0   2107.0
# 330044      2001.0      4.0   2554.0
#
# [330045 rows x 3 columns]

# %%
data_test = test.drop(['ID', 'Tag', 'Username'], axis=1)

# %%
data_ind = pd.concat([data_x, data_test])

# %% [markdown]
# ### Normalisation

# %%
def normalise(data):
    return (data-np.mean(data))/np.std(data)

# %%
def min_max(data):
    return (data - np.min(data))/(np.max(data)-np.min(data))

# %%
def log_reduction(data):
    d = data.copy()
    d[d>0] = np.log(d[d>0])
    return d

# %%
def reverse_log(data):
    d = data.copy()
    d[d>0] = np.exp(d[d>0])
    d[d<0] = 0
    return d

# %%
def normalise_target(data):
    return(data - np.mean(train.Upvotes))/np.std(train.Upvotes)

def rev_normal_target(data):
    return (data*np.std(train.Upvotes)) + np.mean(train.Upvotes)

# %% [markdown]
# ### Feature Engineering

# %%
y = train.Upvotes

# %%
y = y+2e-7

# %%
y.mean()
# Out:
# 337.50535855818964

# %%
data_normalise = normalise(data_ind)

# %%
data_min_max = min_max(data_ind)

# %%
data_log = log_reduction(data_ind)

# %% [markdown]
# ### Result

# %%
def result_df(result):
    result_df = pd.DataFrame(columns=['ID', 'Upvotes'])
    result_df['ID'] = test.ID
    result_df['Upvotes'] = result
    return result_df.set_index('ID', drop=True)

# %% [markdown]
# ## Models

# %%
from sklearn.metrics import r2_score, mean_squared_error
def rmse(true, predicted):
    return np.sqrt(mean_squared_error(true, predicted))

# %% [markdown]
# #### Linear Model

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

# %%
train_x_lin, test_x_lin, train_y_lin, test_y_lin = train_test_split(data_normalise[:330045], train.Upvotes, test_size=0.3, random_state=100)

# %%
lin_mod = LinearRegression()

# %%
lin_mod.fit(train_x_lin, normalise_target(train_y_lin))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = lin_mod.predict(test_x_lin)

# %%
rev_normal_target(pred)
# Out:
# array([ 337.50535836,  599.25126436,  337.50535836, ...,  337.50535836,
#        1284.34125989,  337.50535836])

# %%
pred[pred<0] = 0

# %%
rmse(test_y_lin, rev_normal_target(pred).astype('int32'))
# Out:
# 2938.8910684959224

# %%
res = lin_mod.predict(data_normalise[330045:]).astype('int32')
res[res<0] = 0

# %%
result_df(res).to_csv('/Users/skylark/Desktop/upvotes/result.csv')

# %%
result_df(res)
# Out:
#         Upvotes
# ID
# 366953      356
# 71864       355
# 141692       19
# 316833        0
# 440445      571
# ...         ...
# 47187         0
# 329126      162
# 282334      568
# 386629        0
# 107271        0
#
# [141448 rows x 1 columns]

# %% [markdown]
# #### RandomForest Reg

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
    train_x_rdm, test_x_rdm, train_y_rdm, test_y_rdm = train_test_split(data_ind[:330045], train.Upvotes, test_size=0.3, random_state=100)

# %%
rdm_mod = RandomForestRegressor()

# %%
rdm_mod.fit(train_x_rdm, train_y_rdm)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
pred = rdm_mod.predict(test_x_rdm).astype('int32')

# %%
rmse(test_y_rdm, pred)
# Out:
# 1182.1454505394156

# %%
result_df(rdm_mod.predict(data_ind[330045:]).astype('int32')).to_csv('/Users/skylark/Desktop/upvotes/result.csv')

# %%
params = {'n_estimators':range(10,200), 'max_depth': range(10, 200, 10), 'max_features':['auto', 'sqrt', 0.2, 0.5]}

# %%
rcv = RandomizedSearchCV(rdm_mod, param_distributions=params, cv=5, scoring='r2')
rcv.fit(train_x_rdm, train_y_rdm)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=10, n_jobs=None,
#                                                    oob_score=False,
#                                                    random_state=None, verbose=0,
#                                                    warm_start=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'max_depth': range(10, 200, 10),
#                                         'max_features': ['auto', 'sqrt', 0.2,
#                                                          0.5],
#                                         'n_estimators': range(10, 200)},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='r2', verbose=0)

# %%
rcv.best_params_
# Out:
# {'n_estimators': 25, 'max_features': 'auto', 'max_depth': 20}

# %%
rcv.best_score_
# Out:
# 0.842093548057749

# %%
rdm_mod = RandomForestRegressor(n_estimators=25, max_features='auto', max_depth=20)

# %%
rdm_mod.fit(train_x_rdm, train_y_rdm)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=25,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
pred = rdm_mod.predict(test_x_rdm).astype('int32')

# %%
pred
# Out:
# array([  7, 218,  20, ...,   8,  56,  30], dtype=int32)

# %%
rmse(test_y_rdm, pred)
# Out:
# 1152.3535233283626

# %%
result_df(rdm_mod.predict(data_ind[330045:]).astype('int32')).to_csv('/Users/skylark/Desktop/upvotes/result.csv')

# %% [markdown]
# ### Boosting

# %%
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor

# %%
ada_mod = AdaBoostRegressor(RandomForestRegressor())

# %%
ada_mod.fit(train_x_rdm, train_y_rdm)
# Out:
# AdaBoostRegressor(base_estimator=RandomForestRegressor(bootstrap=True,
#                                                        criterion='mse',
#                                                        max_depth=None,
#                                                        max_features='auto',
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators='warn',
#                                                        n_jobs=None,
#                                                        oob_score=False,
#                                                        random_state=None,
#                                                        verbose=0,
#                                                        warm_start=False),
#                   learning_rate=1.0, loss='linear', n_estimators=50,
#                   random_state=None)

# %%
pred = ada_mod.predict(test_x_rdm).astype('int32')

# %%
rmse(test_y_rdm, pred)
# Out:
# 1189.72123284964

# %%
params = {'base_estimator':[RandomForestRegressor(), LinearRegression(), XGBRegressor()],'n_estimators': range(10, 200, 10), 'learning_rate':np.random.choice(np.array(range(10, 1000))/100, size=20)}

# %%
rdm_cv = RandomizedSearchCV(ada_mod, param_distributions=params, cv=5, scoring='r2')

# %%
rdm_cv.fit(train_x_rdm, train_y_rdm)
# Out:
# [21:33:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21

#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='r2', verbose=0)

# %%
rdm_cv.best_params_
# Out:
# {'n_estimators': 150,
#  'learning_rate': 0.42,
#  'base_estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               importance_type='gain', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#               n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)}

# %%
rdm_cv.best_score_
# Out:
# 0.8417485031779833

# %%
ada_mod = AdaBoostRegressor(XGBRegressor(), n_estimators=150, learning_rate=0.42)

# %%
ada_mod.fit(train_x_rdm, train_y_rdm)
# Out:
# [01:21:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:21:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:21:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:21:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:22:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:22:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:22:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:22:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:22:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:22:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:23:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:23:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:23:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:23:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:23:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:24:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:24:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:24:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:24:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:24:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:25:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:25:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:25:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:25:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:25:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# AdaBoostRegressor(base_estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                               colsample_bylevel=1,
#                                               colsample_bynode=1,
#                                               colsample_bytree=1, gamma=0,
#                                               importance_type='gain',
#                                               learning_rate=0.1,
#                                               max_delta_step=0, max_depth=3,
#                                               min_child_weight=1, missing=None,
#                                               n_estimators=100, n_jobs=1,
#                                               nthread=None,
#                                               objective='reg:linear',
#                                               random_state=0, reg_alpha=0,
#                                               reg_lambda=1, scale_pos_weight=1,
#                                               seed=None, silent=None,
#                                               subsample=1, verbosity=1),
#                   learning_rate=0.42, loss='linear', n_estimators=150,
#                   random_state=None)

# %%
pred = ada_mod.predict(test_x_rdm).astype('int32')

# %%
pred
# Out:
# array([  4, 101,   0, ...,   4, 428,  30], dtype=int32)

# %%
rmse(test_y_rdm, pred)
# Out:
# 1212.16032754516

# %%
xgb_mod = XGBRegressor()

# %%
xgb_mod.fit(train_x_rdm, train_y_rdm)
# Out:
# [01:29:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
xgb_mod.predict(test_x_rdm)
# Out:
# array([-21.439371, 218.58356 , -21.532738, ..., -21.439371, 487.71167 ,
#         13.930687], dtype=float32)

# %%
train_x_rdm
# Out:
#         Reputation  Answers     Views
# 277198     51300.0      2.0    1922.0
# 211769      1337.0      5.0   14354.0
# 287257       419.0      4.0    2312.0
# 57703         25.0      3.0     521.0
# 253787       289.0      4.0   97541.0
# ...            ...      ...       ...
# 65615        708.0      3.0    9708.0
# 253799       696.0     12.0  235312.0
# 210755       859.0      3.0   11844.0
# 56088         88.0      2.0   21465.0
# 300552      2553.0      4.0   45350.0
#
# [231031 rows x 3 columns]

# %%
train.groupby('Tag')['Views'].sum()
# Out:
# Tag
# a    1.007930e+09
# c    1.938011e+09
# h    6.981264e+08
# i    5.121364e+08
# j    3.127011e+09
# o    1.964386e+08
# p    1.440461e+09
# r    1.497153e+08
# s    6.018986e+08
# x    1.124802e+08
# Name: Views, dtype: float64

# %%
train
# Out:
#             ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0        52664   a      3942.0      2.0    155623   7855.0     42.0
# 1       327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177   8067.0     60.0
# 3        96996   a       264.0      3.0    168793  27064.0      9.0
# 4       131465   c      4271.0      4.0    112223  13986.0     83.0
# ...        ...  ..         ...      ...       ...      ...      ...
# 330040  339800   c        36.0      2.0     84919   1063.0      0.0
# 330041  253800   c      1649.0      2.0     76730  23319.0     73.0
# 330042  210756   c      6178.0      2.0     91701   2453.0     15.0
# 330043   56089   j        89.0      2.0     80245   2107.0      3.0
# 330044  300553   j      2001.0      4.0    154692   2554.0     37.0
#
# [330045 rows x 7 columns]
